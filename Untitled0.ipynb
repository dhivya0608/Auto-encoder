# %% [markdown]
# <a href="https://colab.research.google.com/github/dhivya0608/Auto-encoder/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.layers import GaussianNoise

# Load the Fashion MNIST dataset
(x_train, _), (x_test, _) = fashion_mnist.load_data() #TRAIN AND TESTING

# Normalize pixel values to be between 0 and 1
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Flatten the images for the autoencoder
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# Introduce Gaussian noise to the images
noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

# Clip the pixel values to be between 0 and 1
x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# Define the denoising autoencoder model
encoding_dim = 32  # Size of the encoded representations
input_img = Input(shape=(784,))
encoded = Dense(encoding_dim, activation='relu')(input_img)
decoded = Dense(784, activation='sigmoid')(encoded)

autoencoder = Model(input_img, decoded)

# Compile the autoencoder
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Train the denoising autoencoder
autoencoder.fit(x_train_noisy, x_train, epochs=50, batch_size=256, shuffle=True, validation_data=(x_test_noisy, x_test))

# Create a separate encoder model
encoder = Model(input_img, encoded)

# Encode the test images
encoded_imgs = encoder.predict(x_test_noisy)

# Decode the encoded images
decoded_imgs = autoencoder.predict(x_test_noisy)

# Display original, noisy, and reconstructed images
n = 10  # Number of images to display
plt.figure(figsize=(20, 6))
for i in range(n):
    # Original images
    ax = plt.subplot(3, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    ax.set_title('Original')

    # Noisy images
    ax = plt.subplot(3, n, i + 1 + n)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    ax.set_title('Noisy')

    # Reconstructed images
    ax = plt.subplot(3, n, i + 1 + 2*n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    ax.set_title('Reconstructed')

plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step
# Epoch 1/50
# 235/235 [==============================] - 7s 20ms/step - loss: 0.4359 - val_loss: 0.3627
# Epoch 2/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.3431 - val_loss: 0.3364
# Epoch 3/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.3296 - val_loss: 0.3282
# Epoch 4/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.3233 - val_loss: 0.3240
# Epoch 5/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3195 - val_loss: 0.3205
# Epoch 6/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.3165 - val_loss: 0.3179
# Epoch 7/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3139 - val_loss: 0.3155
# Epoch 8/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3118 - val_loss: 0.3136
# Epoch 9/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.3101 - val_loss: 0.3122
# Epoch 10/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3086 - val_loss: 0.3111
# Epoch 11/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3075 - val_loss: 0.3097
# Epoch 12/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3065 - val_loss: 0.3089
# Epoch 13/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3057 - val_loss: 0.3086
# Epoch 14/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.3051 - val_loss: 0.3078
# Epoch 15/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.3046 - val_loss: 0.3075
# Epoch 16/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3042 - val_loss: 0.3070
# Epoch 17/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3039 - val_loss: 0.3066
# Epoch 18/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3036 - val_loss: 0.3064
# Epoch 19/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3034 - val_loss: 0.3062
# Epoch 20/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.3032 - val_loss: 0.3059
# Epoch 21/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3030 - val_loss: 0.3058
# Epoch 22/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3029 - val_loss: 0.3058
# Epoch 23/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3028 - val_loss: 0.3057
# Epoch 24/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3027 - val_loss: 0.3060
# Epoch 25/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.3026 - val_loss: 0.3054
# Epoch 26/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.3025 - val_loss: 0.3054
# Epoch 27/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3023 - val_loss: 0.3053
# Epoch 28/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.3023 - val_loss: 0.3052
# Epoch 29/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3022 - val_loss: 0.3052
# Epoch 30/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3021 - val_loss: 0.3052
# Epoch 31/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.3020 - val_loss: 0.3051
# Epoch 32/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3020 - val_loss: 0.3050
# Epoch 33/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3019 - val_loss: 0.3050
# Epoch 34/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3018 - val_loss: 0.3049
# Epoch 35/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3018 - val_loss: 0.3052
# Epoch 36/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.3017 - val_loss: 0.3047
# Epoch 37/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.3016 - val_loss: 0.3048
# Epoch 38/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3016 - val_loss: 0.3046
# Epoch 39/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.3016 - val_loss: 0.3049
# Epoch 40/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3015 - val_loss: 0.3046
# Epoch 41/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.3015 - val_loss: 0.3045
# Epoch 42/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.3014 - val_loss: 0.3046
# Epoch 43/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.3014 - val_loss: 0.3045
# Epoch 44/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.3014 - val_loss: 0.3047
# Epoch 45/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3013 - val_loss: 0.3044
# Epoch 46/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3013 - val_loss: 0.3046
# Epoch 47/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.3013 - val_loss: 0.3044
# Epoch 48/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.3012 - val_loss: 0.3043
# Epoch 49/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3012 - val_loss: 0.3043
# Epoch 50/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.3011 - val_loss: 0.3044
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 2ms/step
